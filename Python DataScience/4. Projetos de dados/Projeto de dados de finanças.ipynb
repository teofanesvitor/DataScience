# %% [markdown]
# # Projeto de dados do mercado financeiro
#
# Neste projeto de dados, nos concentraremos na análise de dados exploratórios dos preços das ações. Tenha em mente que este projeto apenas pretende praticar suas habilidades de visualização e pandas, não é para ser uma análise financeira robusta ou ser tomado como um conselho financeiro.
# ____
# ** NOTA: Este projeto é extremamente desafiador, porque irá introduzir muitos novos conceitos e te fará procurar as coisas por conta própria (vamos apontar você na direção certa) para tentar resolver as tarefas emitidas. Sinta-se à vontade para passar pelo livro de conferências de soluções e no vídeo como um projeto "passo a passo" se você não quer ter que procurar as coisas sozinho. Você ainda aprenderá muito dessa forma! **
# ____
# Vamos nos concentrar nas ações dos banco e ver como eles performaram durante a [crise financeira](https://en.wikipedia.org/wiki/Financial_crisis_of_2007%E2%80%9308) até o início de 2021.

# %% [markdown]
# ## Obter dados
#
# Nesta seção, aprenderemos a usar pandas para ler diretamente os dados das finanças do Google usando pandas!
#
# Primeiro, precisamos começar com as importações adequadas, que já apresentamos para você aqui.
#
# * Nota: [Você precisará instalar pandas-datareader para que isso funcione!](Https://github.com/pydata/pandas-datareader) O datareader Pandas permite que você [leia informações das ações diretamente da internet](http : //pandas.pydata.org/pandas-docs/stable/remote_data.html) Use estes links para orientação de instalação (** pip install pandas-datareader **), ou simplesmente acompanhe a conferência de vídeo. *

# %%
from pandas_datareader import data, wb
import seaborn as sns
import pandas as pd
import numpy as np
import datetime
# %matplotlib inline

# %% [markdown]
# ## Dados
#
# Precisamos obter dados usando o datareader de pandas. Obteremos informações sobre ações para os seguintes bancos:
# * Bank of America
# * CitiGroup
# * Goldman Sachs
# * JPMorgan Chase
# * Morgan Stanley
# * Wells Fargo
#
# ** Descubra como obter os dados de ações de 1 de janeiro de 2006 a 1º de janeiro de 2016 para cada um desses bancos. Defina cada banco como um dataframe separado, com o nome da variável para que esse banco seja seu símbolo de ticker. Isso envolverá algumas etapas: **
# 1. Use datetime para definir objetos de início e fim de data e hora.
# 2. Descobrir o símbolo do ticker para cada banco.
# 2. Descubra como usar o datareader para pegar as cotações.
#
# ** Use [esta página de documentação](http://pandas.pydata.org/pandas-docs/stable/remote_data.html) para obter dicas e instruções. Use o google finance como um fonte, por exemplo: **
#
#      # Banco da América
#      BAC = data.DataReader ("BAC", "google", início e fim)

# %%
BAC = data.DataReader('BAC', data_source='yahoo', start='01/01/2006', end='01/01/2019')

# %%
C = data.DataReader('C', data_source='yahoo', start='01/01/2006', end='01/01/2019')

# %%
GSBD = data.DataReader('GSBD', data_source='yahoo', start='01/01/2006', end='01/01/2019')

# %%
JPM = data.DataReader('JPM', data_source='yahoo', start='01/01/2006', end='01/01/2019')

# %%
MS = data.DataReader('MS', data_source='yahoo', start='01/01/2006', end='01/01/2019')

# %%
WFC = data.DataReader('WFC', data_source='yahoo', start='01/01/2006', end='01/01/2019')

# %%
BAC['Close'].plot(figsize=(15,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ** Crie uma lista dos símbolos dos tickers (como strings) em ordem alfabética. Chame esta lista: tickers **

# %%
tickers = ['BAC', 'C', 'GSBD', 'JPM', 'MS', 'WFC']

# %% [markdown]
# ** Use pd.concat para concatenar os DataFrames do banco juntos em um único chamado bank_stocks. Defina o argumento das chaves igual à lista de tickers. Também preste atenção em que eixo você concatena. **

# %%
bank_stocks = pd.concat([BAC, C, GSBD, JPM, MS, WFC], axis=1, keys=tickers)

# %%
bank_stocks.columns.names = ['Bank Ticker','Stock Info']

# %%
bank_stocks
# Out:
# Bank Ticker        BAC                                                \
# Stock Info        High        Low       Open      Close       Volume
# Date
# 2006-01-03   47.180000  46.150002  46.919998  47.080002   16296700.0
# 2006-01-04   47.240002  46.450001  47.000000  46.580002   17757900.0
# 2006-01-05   46.830002  46.320000  46.580002  46.639999   14970700.0
# 2006-01-06   46.910000  46.349998  46.799999  46.570000   12599800.0
# 2006-01-09   46.970001  46.360001  46.720001  46.599998   15619400.0
# ...                ...        ...        ...        ...          ...
# 2018-12-24   23.209999  22.660000  22.760000  22.730000   64859100.0
# 2018-12-26   24.180000  22.690001  22.910000  24.110001  100877800.0
# 2018-12-27   24.370001  23.389999  23.780001  24.370001   91575400.0
# 2018-12-28   24.750000  24.260000  24.590000  24.389999   78693800.0
# 2018-12-31   24.969999  24.370001  24.570000  24.639999   56257300.0
#
# Bank Ticker                      C                                      ...  \
# Stock Info   Adj Close        High         Low        Open       Close  ...
# Date                                                                    ...
# 2006-01-03   33.942657  493.799988  481.100006  490.000000  492.899994  ...
# 2006-01-04   33.582172  491.000000  483.500000  488.600006  483.799988  ...
# 2006-01-05   33.625439  487.799988  484.000000  484.399994  486.200012  ...
# 2006-01-06   33.574959  489.000000  482.000000  488.799988  486.200012  ...
# 2006-01-09   33.596603  487.399994  483.000000  486.000000  483.899994  ...
# ...                ...         ...         ...         ...         ...  ...
# 2018-12-24   21.235123   50.250000   48.480000   49.400002   49.259998  ...
# 2018-12-26   22.524364   51.450001   48.419998   49.650002   51.439999  ...
# 2018-12-27   22.767262   51.770000   49.700001   50.619999   51.770000  ...
# 2018-12-28   22.785950   52.549999   51.570000   51.930000   51.830002  ...
# 2018-12-31   23.019503   52.669998   51.389999   51.980000   52.060001  ...
#
# Bank Ticker         MS                                          WFC  \
# Stock Info        Open      Close      Volume  Adj Close       High
# Date
# 2006-01-03   57.169998  58.310001   5377000.0  36.114265  31.975000
# 2006-01-04   58.700001  58.349998   7977800.0  36.139038  31.820000
# 2006-01-05   58.549999  58.509998   5778000.0  36.238132  31.555000
# 2006-01-06   58.770000  58.570000   6889800.0  36.275299  31.775000
# 2006-01-09   58.630001  59.189999   4144500.0  36.659298  31.825001
# ...                ...        ...         ...        ...        ...
# 2018-12-24   37.610001  37.009998  11444400.0  34.101574  45.099998
# 2018-12-26   37.279999  39.299999  16814200.0  36.211609  45.590000
# 2018-12-27   38.480000  39.660000  13897900.0  36.543327  45.529999
# 2018-12-28   39.939999  39.369999  12854200.0  36.276112  46.430000
# 2018-12-31   39.669998  39.650002   9518100.0  36.534107  46.480000
#
# Bank Ticker
# Stock Info         Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03   31.195000  31.600000  31.900000  11016400.0  20.444872
# 2006-01-04   31.365000  31.799999  31.530001  10870000.0  20.207735
# 2006-01-05   31.309999  31.500000  31.495001  10158000.0  20.185310
# 2006-01-06   31.385000  31.580000  31.680000   8403800.0  20.303867
# 2006-01-09   31.555000  31.674999  31.674999   5619600.0  20.300663
# ...                ...        ...        ...         ...        ...
# 2018-12-24   43.599998  44.470001  43.599998  18049900.0  39.755207
# 2018-12-26   43.020000  43.840000  45.590000  27770000.0  41.569733
# 2018-12-27   43.849998  44.720001  45.529999  27005300.0  41.515022
# 2018-12-28   45.529999  45.680000  45.779999  23635000.0  41.742973
# 2018-12-31   45.570000  45.980000  46.080002  16544500.0  42.016514
#
# [3271 rows x 36 columns]

# %% [markdown]
# # Análise de dados exploratória
#
# Vamos explorar os dados um pouco! Antes de prosseguir, sugiro que você verifique a documentação no [Multi-Level Indexing](http://pandas.pydata.org/pandas-docs/stable/advanced.html) e [como usar .xs](http: // pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.xs.html).
# Consulte as soluções se você não consiga descobrir como usar .xs (), uma vez que isso será uma parte importante desse projeto.
#
# ** Qual é o preço máximo de fechamento para cada banco durante todo o período? **

# %%
bank_stocks.xs('Close', axis=1, level='Stock Info').min()
# Out:
# Bank Ticker
# BAC      3.14
# C       10.20
# GSBD    17.41
# JPM     15.90
# MS       9.20
# WFC      8.12
# dtype: float64

# %% [markdown]
# ** Crie um novo DataFrame vazio chamado returns. Este dataframe conterá os retornos para o ação de cada banco. Os retornos geralmente são definidos por: **
#
# $$r_t = \frac{p_t - p_{t-1}}{p_{t-1}} = \frac{p_t}{p_{t-1}} - 1$$

# %% [markdown]
# ** Podemos usar o método pct_change () pandas na coluna close para criar uma coluna que represente esse valor de retorno. Crie um loop for que vá e para cada Bank Stock Ticker cria essa coluna de retorno e configura-a como uma coluna nos dados DataFrame. **

# %%
returns = pd.DataFrame()
for w in tickers:
    returns[w + ' Returns'] = bank_stocks[w]['Close'].pct_change()
returns
# Out:
#             BAC Returns  C Returns  GSBD Returns  JPM Returns  MS Returns  \
# Date
# 2006-01-03          NaN        NaN           NaN          NaN         NaN
# 2006-01-04    -0.010620  -0.018462           NaN    -0.014183    0.000686
# 2006-01-05     0.001288   0.004961           NaN     0.003029    0.002742
# 2006-01-06    -0.001501   0.000000           NaN     0.007046    0.001025
# 2006-01-09     0.000644  -0.004731           NaN     0.016242    0.010586
# ...                 ...        ...           ...          ...         ...
# 2018-12-24    -0.027386  -0.019506      0.006034    -0.021557   -0.017781
# 2018-12-26     0.060713   0.044255      0.054526     0.041459    0.061875
# 2018-12-27     0.010784   0.006415      0.000517     0.011255    0.009160
# 2018-12-28     0.000821   0.001159     -0.026357    -0.002164   -0.007312
# 2018-12-31     0.010250   0.004438     -0.024416     0.008159    0.007112
#
#             WFC Returns
# Date
# 2006-01-03          NaN
# 2006-01-04    -0.011599
# 2006-01-05    -0.001110
# 2006-01-06     0.005874
# 2006-01-09    -0.000158
# ...                 ...
# 2018-12-24    -0.033688
# 2018-12-26     0.045642
# 2018-12-27    -0.001316
# 2018-12-28     0.005491
# 2018-12-31     0.006553
#
# [3271 rows x 6 columns]

# %%
returns['BAC Returns'].plot(figsize=(10,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ** Crie um parplot utilizando seaborn no dataframe de retorno. **

# %%
sns.pairplot(returns[1:])

# %% [markdown]
# ** Usando o seu DataFrame returns, descubra quais datas cada ação dos bancos teve o melhor e o pior dia de retorno. Você deve notar que 4 dos bancos compartilham o mesmo dia para a pior queda. Alguma coisa significante aconteceu naquele dia? **

# %%
returns.idxmin()
# Out:
# BAC Returns    2009-01-20
# C Returns      2009-02-27
# GSBD Returns   2015-08-21
# JPM Returns    2009-01-20
# MS Returns     2008-10-09
# WFC Returns    2009-01-20
# dtype: datetime64[ns]

# %%
returns.idxmax()
# Out:
# BAC Returns    2009-04-09
# C Returns      2008-11-24
# GSBD Returns   2018-05-07
# JPM Returns    2009-01-21
# MS Returns     2008-10-13
# WFC Returns    2008-07-16
# dtype: datetime64[ns]

# %% [markdown]
# ** Dê uma olhada no desvio padrão dos retornos. Qual ação você classificaria como a mais arriscada durante todo o período de tempo? Qual você classificaria como a mais arriscado para o ano 2015? **

# %%
returns.std()
# Out:
# BAC Returns     0.033128
# C Returns       0.034764
# GSBD Returns    0.012439
# JPM Returns     0.025108
# MS Returns      0.034189
# WFC Returns     0.027339
# dtype: float64

# %%
returns2015 = returns[(datetime.date(2016,1,1) > returns.index.date) & (returns.index.date >= datetime.date(2015,1,1))]
returns2015.std()
# Out:
# BAC Returns     0.016163
# C Returns       0.015289
# GSBD Returns    0.017177
# JPM Returns     0.014017
# MS Returns      0.016249
# WFC Returns     0.012591
# dtype: float64

# %% [markdown]
# ** Crie um distplot usando seaborn dos retornos de 2015 para Morgan Stanley **

# %%
sns.displot(returns2015['MS Returns'], rug=True)

# %% [markdown]
# ** Crie um distplot usando seaborn dos retornos de 2008 para CitiGroup **

# %%
returns2009 = returns[(datetime.date(2009,1,1) > returns.index.date) & (returns.index.date >= datetime.date(2008,1,1))]
sns.displot(returns2009['C Returns'], rug=True)

# %% [markdown]
# # Mais visualização
#
# Muito desse projeto se concentrará em visualizações. Sinta-se livre para usar qualquer uma das suas bibliotecas de visualização preferidas para tentar recriar os plots descritos abaixo, seaborn, matplotlib, plotly e cufflinks, ou apenas pandas.
#
# ### Importações

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %% [markdown]
# ** Crie um gráfico de linha mostrando o preço de fechamento para cada banco para todo o índice de tempo. (Sugestão: tente usar um loop for ou use [.xs](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.xs.html) para obter uma seção transversal dos dados .) **

# %%
for w in tickers:
    bank_stocks[w]['Close'].plot(figsize=(15,4), label=w)
plt.legend()

# %%
bank_stocks.xs(key='Close', level='Stock Info', axis=1).plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Médias móveis
#
# Vamos analisar as médias móveis para essas ações no ano de 2008.
#
# ** Trace a média de 30 dias para o preço do Bank Of America para o ano de 2008 **

# %%
BAC2008 = BAC['Close'][BAC.index.year == 2008]

# %%
BAC2008_mv = BAC2008.rolling(window=30).mean()

# %%
BAC2008_mv
# Out:
# Date
# 2008-01-02          NaN
# 2008-01-03          NaN
# 2008-01-04          NaN
# 2008-01-07          NaN
# 2008-01-08          NaN
#                 ...
# 2008-12-24    14.738667
# 2008-12-26    14.617333
# 2008-12-29    14.478667
# 2008-12-30    14.372667
# 2008-12-31    14.341000
# Name: Close, Length: 253, dtype: float64

# %%
plt.figure(figsize=(15,4))
BAC2008_mv.plot(label='30 day avg')
BAC2008.plot(label='BAC Close')
plt.legend()

# %% [markdown]
# ** Crie um mapa de calor da correlação entre os preços de fechamento das ações. **

# %%
close_data = bank_stocks.xs(key='Close', level='Stock Info', axis=1)

# %%
sns.heatmap(close_data.corr(), annot=True)
# Out:
# <AxesSubplot:xlabel='Bank Ticker', ylabel='Bank Ticker'>

# %% [markdown]
# ** Opcional: use o clustermap do seaborn para agrupar as correlações: **

# %%
sns.clustermap(close_data.corr(), annot=True)

# %% [markdown]
# Definitivamente, muitos tópicos de finanças específicos aqui, então não se preocupe se você não os entendeu todos! A única coisa que você deve estar preocupado com a compreensão são os pandas básicos e operações de visualização.
